# %%
import pandas as pd 
import nltk
import nltk.corpus
import os

# %%
print(os.listdir(nltk.data.find("corpora")))
# Out:
# ['abc', 'abc.zip', 'alpino', 'alpino.zip', 'biocreative_ppi', 'biocreative_ppi.zip', 'brown', 'brown.zip', 'brown_tei', 'brown_tei.zip', 'cess_cat', 'cess_cat.zip', 'cess_esp', 'cess_esp.zip', 'chat80', 'chat80.zip', 'city_database', 'city_database.zip', 'cmudict', 'cmudict.zip', 'comparative_sentences', 'comparative_sentences.zip', 'comtrans.zip', 'conll2000', 'conll2000.zip', 'conll2002', 'conll2002.zip', 'conll2007.zip', 'crubadan', 'crubadan.zip', 'dependency_treebank', 'dependency_treebank.zip', 'dolch', 'dolch.zip', 'europarl_raw', 'europarl_raw.zip', 'floresta', 'floresta.zip', 'framenet_v15', 'framenet_v15.zip', 'framenet_v17', 'framenet_v17.zip', 'gazetteers', 'gazetteers.zip', 'genesis', 'genesis.zip', 'gutenberg', 'gutenberg.zip', 'ieer', 'ieer.zip', 'inaugural', 'inaugural.zip', 'indian', 'indian.zip', 'jeita.zip', 'kimmo', 'kimmo.zip', 'knbc.zip', 'lin_thesaurus', 'lin_thesaurus.zip', 'machado.zip', 'mac_morpho', 'mac_morpho.zip', 'masc_tagged.zip', 'movie_reviews', 'mov
# ...

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
hamlet=nltk.corpus.gutenberg.words("shakespeare-hamlet.txt") ##tokenized file  ## word tokenize file

# %%
hamlet1=nltk.corpus.gutenberg.raw ('shakespeare-hamlet.txt') # word file

# %%
type(hamlet1)
# Out:
# str

# %%
from nltk.tokenize import word_tokenize

# %%
ai_token=word_tokenize(hamlet1)

# %%
len(ai_token)
# Out:
# 36382

# %%
from nltk.probability import FreqDist

# %%
fdist=FreqDist()

# %%
for word in word_tokenize(hamlet1):
        fdist[word.lower()] += 1
fdist
# Out:
# FreqDist({',': 2892, '.': 1879, 'the': 993, 'and': 862, 'to': 683, 'of': 610, ':': 566, 'i': 560, 'you': 527, 'my': 502, ...})

# %%
for word in ai_token:
        fdist[word.lower()] += 1
fdist
# Out:
# FreqDist({',': 5784, '.': 3758, 'the': 1986, 'and': 1724, 'to': 1366, 'of': 1220, ':': 1132, 'i': 1120, 'you': 1054, 'my': 1004, ...})

# %%
fdist_10=fdist.most_common(10)

# %%
fdist_10
# Out:
# [(',', 5784),
#  ('.', 3758),
#  ('the', 1986),
#  ('and', 1724),
#  ('to', 1366),
#  ('of', 1220),
#  (':', 1132),
#  ('i', 1120),
#  ('you', 1054),
#  ('my', 1004)]

# %%
from nltk.tokenize import blankline_tokenize

# %%
ai_blank=blankline_tokenize(hamlet1)

# %%
len(ai_blank) ## no of paragraphs seperated ny new lines
# Out:
# 950

# %%
from nltk.util import bigrams,trigrams,ngrams

# %%
string ="The best and most beautifuk things of the world can not be seen or wvwn touched, those must be felt with heart"

# %%
tokens=nltk.word_tokenize(string)

# %%
bigr=list(nltk.bigrams(tokens))

# %%
(bigr)
# Out:
# [('The', 'best'),
#  ('best', 'and'),
#  ('and', 'most'),
#  ('most', 'beautifuk'),
#  ('beautifuk', 'things'),
#  ('things', 'of'),
#  ('of', 'the'),
#  ('the', 'world'),
#  ('world', 'can'),
#  ('can', 'not'),
#  ('not', 'be'),
#  ('be', 'seen'),
#  ('seen', 'or'),
#  ('or', 'wvwn'),
#  ('wvwn', 'touched'),
#  ('touched', ','),
#  (',', 'those'),
#  ('those', 'must'),
#  ('must', 'be'),
#  ('be', 'felt'),
#  ('felt', 'with'),
#  ('with', 'heart')]

# %%
trig=list(nltk.trigrams(tokens))

# %%
trig
# Out:
# [('The', 'best', 'and'),
#  ('best', 'and', 'most'),
#  ('and', 'most', 'beautifuk'),
#  ('most', 'beautifuk', 'things'),
#  ('beautifuk', 'things', 'of'),
#  ('things', 'of', 'the'),
#  ('of', 'the', 'world'),
#  ('the', 'world', 'can'),
#  ('world', 'can', 'not'),
#  ('can', 'not', 'be'),
#  ('not', 'be', 'seen'),
#  ('be', 'seen', 'or'),
#  ('seen', 'or', 'wvwn'),
#  ('or', 'wvwn', 'touched'),
#  ('wvwn', 'touched', ','),
#  ('touched', ',', 'those'),
#  (',', 'those', 'must'),
#  ('those', 'must', 'be'),
#  ('must', 'be', 'felt'),
#  ('be', 'felt', 'with'),
#  ('felt', 'with', 'heart')]

# %%
(ngram)=list(nltk.ngrams(tokens,5))

# %%
ngram
# Out:
# [('The', 'best', 'and', 'most', 'beautifuk'),
#  ('best', 'and', 'most', 'beautifuk', 'things'),
#  ('and', 'most', 'beautifuk', 'things', 'of'),
#  ('most', 'beautifuk', 'things', 'of', 'the'),
#  ('beautifuk', 'things', 'of', 'the', 'world'),
#  ('things', 'of', 'the', 'world', 'can'),
#  ('of', 'the', 'world', 'can', 'not'),
#  ('the', 'world', 'can', 'not', 'be'),
#  ('world', 'can', 'not', 'be', 'seen'),
#  ('can', 'not', 'be', 'seen', 'or'),
#  ('not', 'be', 'seen', 'or', 'wvwn'),
#  ('be', 'seen', 'or', 'wvwn', 'touched'),
#  ('seen', 'or', 'wvwn', 'touched', ','),
#  ('or', 'wvwn', 'touched', ',', 'those'),
#  ('wvwn', 'touched', ',', 'those', 'must'),
#  ('touched', ',', 'those', 'must', 'be'),
#  (',', 'those', 'must', 'be', 'felt'),
#  ('those', 'must', 'be', 'felt', 'with'),
#  ('must', 'be', 'felt', 'with', 'heart')]

# %%
## stemming

# %%
from nltk.stem import PorterStemmer

# %%
ps=PorterStemmer()

# %%
word=["give","given","giver","giving"]

# %%
for i in word:
    print(ps.stem(i))
# Out:
# give
# given
# giver
# give

# %%
from nltk.stem import LancasterStemmer

# %%
ls=LancasterStemmer()

# %%
for i in word:                   ### more aggrasive than of stem 
    print(i,":",ls.stem(i))
# Out:
# give : giv
# given : giv
# giver : giv
# giving : giv

# %% [markdown]
# # Lemmatization of words is morphological analysis of wordss

# %%
from nltk.stem import wordnet
from nltk.stem import WordNetLemmatizer

# %%
word_lem=WordNetLemmatizer()

# %%
word_lem.lemmatize("corpora")
# Out:
# 'corpus'

# %%
for i in word:
    print(i,":",word_lem.lemmatize(i))
# Out:
# give : give
# given : given
# giver : giver
# giving : giving

# %%
word=['go',"went","gone"]

# %% [markdown]
# # name entity recognization

# %%
us="The US President lives in White_House from 1992  "

# %%
us_word=word_tokenize(us)

# %%
from nltk import ne_chunk

# %%
tok=nltk.pos_tag(us_word)

# %%
entity=ne_chunk(tok)

# %%
print(entity)
# Out:
# (S
#   The/DT
#   (ORGANIZATION US/NNP)
#   President/NNP
#   lives/VBZ
#   in/IN
#   (GPE White_House/NNP)
#   from/IN
#   1992/CD)

# %%
# entity.draw()

# %%
print(os.listdir(nltk.data.find("corpora")))
# Out:
# ['abc', 'abc.zip', 'alpino', 'alpino.zip', 'biocreative_ppi', 'biocreative_ppi.zip', 'brown', 'brown.zip', 'brown_tei', 'brown_tei.zip', 'cess_cat', 'cess_cat.zip', 'cess_esp', 'cess_esp.zip', 'chat80', 'chat80.zip', 'city_database', 'city_database.zip', 'cmudict', 'cmudict.zip', 'comparative_sentences', 'comparative_sentences.zip', 'comtrans.zip', 'conll2000', 'conll2000.zip', 'conll2002', 'conll2002.zip', 'conll2007.zip', 'crubadan', 'crubadan.zip', 'dependency_treebank', 'dependency_treebank.zip', 'dolch', 'dolch.zip', 'europarl_raw', 'europarl_raw.zip', 'floresta', 'floresta.zip', 'framenet_v15', 'framenet_v15.zip', 'framenet_v17', 'framenet_v17.zip', 'gazetteers', 'gazetteers.zip', 'genesis', 'genesis.zip', 'gutenberg', 'gutenberg.zip', 'ieer', 'ieer.zip', 'inaugural', 'inaugural.zip', 'indian', 'indian.zip', 'jeita.zip', 'kimmo', 'kimmo.zip', 'knbc.zip', 'lin_thesaurus', 'lin_thesaurus.zip', 'machado.zip', 'mac_morpho', 'mac_morpho.zip', 'masc_tagged.zip', 'movie_reviews', 'mov
# ...

# %%
from nltk.corpus import movie_reviews

# %%
print(movie_reviews.categories())
# Out:
# ['neg', 'pos']

# %% [markdown]
# # nlp

# %%
import pandas as pd

# %%
dataset=pd.read_csv("Restaurant_Reviews.tsv",delimiter="\t",quoting=3)

# %%
dataset.head()
# Out:
#                                               Review  Liked
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1

# %%
import re

# %% [raw]
# # cleaning of text

# %%
dataset.Review[0]
# Out:
# 'Wow... Loved this place.'

# %%
review=re.sub("[^a-zA-Z]"," ",dataset.Review[0])

# %%
review
# Out:
# 'Wow    Loved this place '

# %%
an="anl patidar $$ ..??? 0 tu 8747 hsdusm 5581 jjckdn000 " ## ex not to remove no

# %%
re.sub("[^a-zA-Z0-9]"," ",an)
# Out:
# 'anl patidar          0 tu 8747 hsdusm 5581 jjckdn000 '

# %%
review=review.lower()

# %%
import nltk

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sandY\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# since review is str hence we have to split it

# %%
review=review.split()

# %%
review
# Out:
# ['wow', 'loved', 'this', 'place']

# %%
review
# Out:
# ['wow', 'loved', 'this', 'place']

# %%
from nltk.corpus import stopwords

# %%
from nltk.stem.porter import PorterStemmer

# %%
ps=PorterStemmer

# %%
review=[word for word in review if not word in set(stopwords.words("english"))] #review=[ps.stem(word) for word in review if not word in set(stopwords.words("english"))]

# %%
review
# Out:
# ['wow', 'loved', 'place']

# %%
review=" ".join(review)

# %%
review
# Out:
# 'wow loved place'

# %%
# do it for all the dataset

# %%
corpus=[]

# %%
dataset.shape
# Out:
# (1000, 2)

# %%
for i in range(0,1000):
    review=re.sub("[^a-zA-Z]"," ",dataset.Review[i])
    review=review.lower()
    review=review.split()
    review=[word for word in review if not word in set(stopwords.words("english"))]
    review=" ".join(review)
    corpus.append(review)

# %%
corpus[0:5]
# Out:
# ['wow loved place',
#  'crust good',
#  'tasty texture nasty',
#  'stopped late may bank holiday rick steve recommendation loved',
#  'selection menu great prices']

# %%
# Creating the Bag of Words model
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
X = cv.fit_transform(corpus).toarray()
y = dataset.iloc[:, 1].values

# %%
# Creating the Bag of Words model
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 1500)
X = cv.fit_transform(corpus).toarray()
y = dataset.iloc[:, 1].values

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %%
# Fitting Naive Bayes to the Training set
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)

# %%
classifier.score(X_test,y_test)
# Out:
# 0.695

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
cm
# Out:
# array([[50, 47],
#        [14, 89]], dtype=int64)

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
nb=MultinomialNB()

# %%
nb.fit(X_train,y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
nb.score(X_test,y_test)
# Out:
# 0.75

# %%
dataset.Liked.value_counts(normalize=True)
# Out:
# 1    0.5
# 0    0.5
# Name: Liked, dtype: float64

# %%
feature_name=cv.get_feature_names()

# %%
o_count=nb.feature_count_[0,:]

# %%
one_count=nb.feature_count_[1,:]

# %%
# create a DataFrame of tokens with their separate ham and spam counts
tokens = pd.DataFrame({'token':feature_name, 'ham':o_count, 'spam':one_count}).set_index('token')
tokens.tail()
# Out:
#        ham  spam
# token
# yucky  1.0   0.0
# yukon  0.0   1.0
# yum    0.0   0.0
# yummy  1.0   3.0
# zero   5.0   0.0

# %%
tokens.sample(5)
# Out:
#         ham  spam
# token
# wall    1.0   0.0
# fare    1.0   0.0
# area    2.0   4.0
# combos  0.0   0.0
# wife    1.0   1.0

# %%
print(nb.class_count_)
# Out:
# [403. 397.]

# %%
# add 1 to ham and spam counts to avoid dividing by 0
tokens['ham'] = tokens.ham + 1
tokens['spam'] = tokens.spam + 1
tokens.sample(5, random_state=6)
# Out:
#          ham  spam
# token
# alone    2.0   1.0
# turn     2.0   1.0
# greeted  1.0   1.0
# read     2.0   1.0
# speedy   1.0   2.0

# %%
# convert the ham and spam counts into frequencies
tokens['ham'] = tokens.ham / nb.class_count_[0]
tokens['spam'] = tokens.spam / nb.class_count_[1]
tokens.sample(5, random_state=6)
# Out:
#               ham      spam
# token
# alone    0.004963  0.002519
# turn     0.004963  0.002519
# greeted  0.002481  0.002519
# read     0.004963  0.002519
# speedy   0.002481  0.005038

# %%
# calculate the ratio of spam-to-ham for each token
tokens['spam_ratio'] = tokens.spam / tokens.ham
tokens.sample(5, random_state=6)
# Out:
#               ham      spam  spam_ratio
# token
# alone    0.004963  0.002519    0.507557
# turn     0.004963  0.002519    0.507557
# greeted  0.002481  0.002519    1.015113
# read     0.004963  0.002519    0.507557
# speedy   0.002481  0.005038    2.030227

# %%
# examine the DataFrame sorted by spam_ratio
# note: use sort() instead of sort_values() for pandas 0.16.2 and earlier
tokens.sort_values('spam_ratio', ascending=False)
# Out:
#                     ham      spam  spam_ratio
# token
# great          0.002481  0.151134   60.906801
# delicious      0.002481  0.050378   20.302267
# awesome        0.002481  0.027708   11.166247
# perfect        0.002481  0.025189   10.151134
# fantastic      0.002481  0.025189   10.151134
# loved          0.002481  0.022670    9.136020
# happy          0.002481  0.022670    9.136020
# spot           0.002481  0.020151    8.120907
# excellent      0.002481  0.017632    7.105793
# beer           0.002481  0.017632    7.105793
# town           0.002481  0.017632    7.105793
# amazing        0.007444  0.050378    6.767422
# bacon          0.002481  0.015113    6.090680
# check          0.002481  0.015113    6.090680
# spicy          0.002481  0.015113    6.090680
# wonderful      0.002481  0.015113    6.090680
# tender         0.002481  0.015113    6.090680
# friendly       0.007444  0.045340    6.090680
# bread          0.002481  0.012594    5.075567
# ...
